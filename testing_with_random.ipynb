# %%
import pandas_profiling
from pyspark.sql import SparkSession
from pyspark import SparkContext, SparkConf
import pandas as pd

spark = SparkSession\
.builder\
.master('local')\
.appName('Capstone_Project')\
.config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.3")\
.getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-0B0SUDVA:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Capstone_Project</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#Dependencies
import pandas as pd
import time
from pyspark.sql import functions as F
from pyspark.sql.functions import isnan, when, count, col
from pyspark.sql.types import TimestampType
import pandas_profiling as pdf

# %%
#####Spark dataframe
testing_df = spark.read.csv(r'C:\Users\luisj\Documents\Project Folders\Pandas_profiling\testing_lg.csv', header=True)

# %% [markdown]
# ## Spark describe function:
# - This function gives you a count, min, max and standar deviation at a column level.
# - This might be useful if we format the information to add into the profiling_table in hive as it runs min, max and count in one line of code.
# - We can select just the columns that we require i.e. scr_sys and business_date
# - The table below is the output after running it in a table of 100 rows with random data

# %%
####spark describe
profilingt_df = testing_df.describe().toPandas()
profilingt_df
# Out:
#   summary                 p_id p_inst_id p_src_id                 a_id  \
# 0   count                   99        99       99                   99
# 1    mean  5.827301227676767E8      None     None  5.387659204040405E8
# 2  stddev  2.437335724680058E8      None     None  2.586293779107589E8
# 3     min            123603164       ABC      DEF            112815503
# 4     max            986873542       ABC      DEF            998871315
#
#   a_inst_id a_src_id p_a_role_cd p_a_strt_dt             m_ch c_flg  \
# 0        99       99          99          99               99    99
# 1      None     None        None        None             None  None
# 2      None     None        None        None             None  None
# 3       ABC      SRC         OOO        NULL  AC8720717025944     N
# 4       ABC      SRC         OWN        NULL  ZY1868772203810     N
#
#    e_fd_r_id p_a_role p_a_shrt_nm d_mail_p_id d_mail_p_cd     e_b_day  \
# 0         99       99          99          99          99          99
# 1  1234567.0     None        None        None        None        None
# 2        0.0     None        None        None        None        None
# 3    1234567     NULL        NULL        NULL        NULL  05/05/2019
# 4    1234567     NULL        NULL        NULL        NULL  20/01/2019
#
#   s_sys_id s_sys_inst_id
# 0       99            99
# 1     None          None
# 2     None          None
# 3      AAA           ABC
# 4      CCC           ABC

# %% [markdown]
# ## Pandas describe function:
# - The pandas describe function gives you the count, unique, top and frequency at a column level
# - Testing is required to understand pandas performance due that Pandas is not optimize for parallel processing with Hive as Spark is, therefore running out of memory while executing the method or storing a larga dataframe in memory is at risk.

# %%
pd_testing_df = testing_df.toPandas()
pd_testing_df.describe()
# Out:
#              p_id p_inst_id p_src_id       a_id a_inst_id a_src_id  \
# count          99        99       99         99        99       99
# unique         99         1        1         99         1        1
# top     773362397       ABC      DEF  480181025       ABC      SRC
# freq            1        99       99          1        99       99
#
#        p_a_role_cd p_a_strt_dt             m_ch c_flg e_fd_r_id p_a_role  \
# count           99          99               99    99        99       99
# unique           3           1               99     1         1        1
# top            OWN        NULL  KQ9963601117174     N   1234567     NULL
# freq            91          99                1    99        99       99
#
#        p_a_shrt_nm d_mail_p_id d_mail_p_cd     e_b_day s_sys_id s_sys_inst_id
# count           99          99          99          99       99            99
# unique           1           1           1           3        3             1
# top           NULL        NULL        NULL  10/10/2019      BBB           ABC
# freq            99          99          99          47       52            99

# %% [markdown]
# ## Pandas profiling
# - Below is the code to get the pandas profiling report.
# - This report provides a summary at a table level and distinct, count, null at a column level. This summary also includes count per distinct per column, allowing to know the number of rows per business_date and source
# - To get this running we need to put an entire table or desired columns into a pandas dataframe.
# - Running out of memory error could occur as pandas is not optimized to be used in a distributed environment like hive. It need to be tested

# %%
from pandas_profiling import ProfileReport
profile_report = ProfileReport(pd_testing_df, minimal=True)
profile_report.to_file(output_file='output.html')
# Out:
# variables: 100%|██████████| 18/18 [00:00<00:00, 82.95it/s]
# table: 100%|██████████| 1/1 [00:00<00:00, 71.59it/s]
# warnings [correlations]: 100%|██████████| 3/3 [00:00<00:00, 750.73it/s]
# package: 100%|██████████| 1/1 [00:00<00:00, 111.12it/s]
# build report structure: 100%|██████████| 1/1 [00:00<00:00, 32.18it/s]

# %% [markdown]
# # Pyspark method
# -This method runs describe in a spark dataframe and complement with other methods in spark to fill gaps that spark describe doesn't provide like null values count
# - The output is a pandas dataframe that can be moved into a hive dataframe to join with the profiling table.

# %%
database_name = 'database_name1'
table_name = 'part_agreement_ss'
df_to_profile = testing_df
df_columns_to_profile = df_to_profile.columns

# %%
profiling_df = pd.DataFrame({'database_name':[database_name] * len(df_to_profile.columns),\
                                        'table_name':[table_name] * len(df_to_profile.columns),\
                                        'column_names':df_to_profile.columns,\
                                        'data_types': [x[1] for x in df_to_profile.dtypes]})
print('initial profiling dataframe created')
# Out:
# initial profiling dataframe created

# %%
#####row_counts
num_rows = df_to_profile.count()
profiling_df['num_rows'] = num_rows
print('num of rows included in the profiling')
# Out:
# num of rows included in the profiling

# %%
#####count nulls 
df_nulls_nan = df_to_profile.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_to_profile.columns if df_to_profile.select(c).dtypes[0][1] != 'timestamp']).toPandas().transpose()
df_nulls_nan = df_nulls_nan.reset_index()
df_nulls_nan.columns = ['column_names', 'num_null']
profiling_df = pd.merge(profiling_df, df_nulls_nan, on = ['column_names'], how = 'left')

# %%
#####describe_function
df_describe_function = df_to_profile.describe().toPandas().transpose()
df_describe_function.columns = ['count', 'mean', 'standar_dev', 'min', 'max']
df_describe_function = df_describe_function.iloc[1:,:]
df_describe_function = df_describe_function.reset_index()
df_describe_function.columns.values[0] = 'column_names'
df_describe_function = df_describe_function[['column_names', 'count', 'mean', 'standar_dev', 'min', 'max']]
profiling_df = pd.merge(profiling_df, df_describe_function, on =['column_names'], how = 'left')

# %%
def color_negative_red(val):
    if type(val) == int:
        if val <= 0:
            color = 'red'
        elif val > 0:
            color = 'green'
        else:
            color = 'black'
    else:
        color = 'black'
    #color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
profiling_df.style.applymap(color_negative_red)
# Out:
# <style  type="text/css" >
#     #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row0_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row1_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row2_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row3_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row4_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row5_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row6_col10 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col0 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col1 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col2 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col3 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col4 {
#             color:  green;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col5 {
#             color:  red;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col6 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col7 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col8 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col9 {
#             color:  black;
#         }    #T_8f363e00_7432_11ea_bc53_04ed338b9cf4row7_col10 {
